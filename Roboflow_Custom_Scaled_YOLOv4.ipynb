# %% [markdown]
# # How to Train Scaled-YOLOv4 on Custom Objects
#
# Scaled-YOLOv4 uses the same training procedures as YOLOv5.
#
# This tutorial is based on the [YOLOv5 repository](https://github.com/ultralytics/yolov5) by [Ultralytics](https://www.ultralytics.com/). This notebook shows training on **your own custom objects**. Many thanks to Ultralytics for putting this repository together - we hope that in combination with clean data management tools at Roboflow, this technologoy will become easily accessible to any developer wishing to use computer vision in their projects.
#
# ### Accompanying Blog Post
#
# A blog on Scaled-YOLOv4 is to come, in the meantime having the blog for [how to train YOLOv5](https://blog.roboflow.ai/how-to-train-yolov5-on-a-custom-dataset/)will be useful.
#
# ### Steps Covered in this Tutorial
#
# In this tutorial, we will walk through the steps required to train Scaled-YOLOv4 on your custom objects. We use a [public blood cell detection dataset](https://public.roboflow.ai/object-detection/bccd), which is open source and free to use. You can also use this notebook on your own data.
#
# To train our detector we take the following steps:
#
# * Install Scaled-YOLOv4 dependencies
# * Download custom Scaled-YOLOv4 object detection data
# * Write our Scaled-YOLOv4 Training configuration
# * Run Scaled-YOLOv4 training
# * Evaluate Scaled-YOLOv4 performance
# * Visualize Scaled-YOLOv4 training data
# * Run Scaled-YOLOv4 inference on test images
# * Export saved Scaled-YOLOv4 weights for future inference
#
#
#
# ### **About**
#
# [Roboflow](https://roboflow.com) enables teams to deploy custom computer vision models quickly and accurately. Convert data from to annotation format, assess dataset health, preprocess, augment, and more. It's free for your first 1000 source images.
#
# **Looking for a vision model available via API without hassle? Try Roboflow Train.**
#
# ![Roboflow Wordmark](https://i.imgur.com/dcLNMhV.png)

# %% [markdown]
# #Install Dependencies
#
# _(Remember to choose GPU in Runtime if not already selected. Runtime --> Change Runtime Type --> Hardware accelerator --> GPU)_

# %%
# %cd C:/Users/WMNL/scaled-yolov4_E7

# clone Scaled_YOLOv4
# !git clone https://github.com/roboflow-ai/ScaledYOLOv4.git  # clone repo
# %cd ScaledYOLOv4
#checkout the yolov4-large branch
# !git checkout yolov4-large
# Out:
# C:\Users\WMNL\scaled-yolov4_E7
# [WinError 2] 系統找不到指定的檔案。: 'ScaledYOLOv4'
# C:\Users\WMNL\scaled-yolov4_E7
# fatal: Too many arguments.
#
# usage: git clone [<options>] [--] <repo> [<dir>]
#
#     -v, --verbose         be more verbose
#     -q, --quiet           be more quiet
#     --progress            force progress reporting
#     -n, --no-checkout     don't create a checkout
#     --bare                create a bare repository
#     --mirror              create a mirror repository (implies bare)
#     -l, --local           to clone from a local repository
#     --no-hardlinks        don't use local hardlinks, always copy
#     -s, --shared          setup as shared repository
#     --recurse-submodules[=<pathspec>]
#                           initialize submodules in the clone
#     --recursive ...       alias of --recurse-submodules
#     -j, --jobs <n>        number of submodules cloned in parallel
#     --template <template-directory>
#                           directory from which templates will be used
#     --reference <repo>    reference repository
#     --reference-if-able <repo>
#                           reference repository
#     --dissociate          use --reference only while cloning
#     -o, --origin <name>   use <name> instead of 'origin' to track upstream
#     -b, --branch <branch>
#                           checkout <branch> instead of the remote's HEAD
#     -u, --upload-pack <path>
#                           path to git-upload-pack on the remote
#     --depth <depth>       create a shallow clone of that depth
#     --shallow-since <time>
#                           create a shallow clone since a specific time
#     --shallow-exclude <revision>
#                           deepen history of shallow clone, excluding rev
#     --single-branch       clone only one branch, HEAD or --branch
#     --no-tags             don't clone any tags, and make later fetches not to follow them
#     --shallow-submodules  any cloned submodules will be shallow
#     --separate-git-dir <gitdir>
#                           separate git dir from working tree
#     -c, --config <key=value>
#                           set config inside the new repository
#     --server-option <server-specific>
#                           option to transmit
#     -4, --ipv4            use IPv4 addresses only
#     -6, --ipv6            use IPv6 addresses only
#     --filter <args>       object filtering
#     --remote-submodules   any cloned submodules will use their remote-tracking branch
#     --sparse              initialize sparse-checkout file to include only files at root
#
# error: pathspec 'yolov4-large' did not match any file(s) known to git

# %%
import torch
print('Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Using torch 1.7.1 _CudaDeviceProperties(name='NVIDIA GeForce RTX 3080', major=8, minor=6, total_memory=10239MB, multi_processor_count=68)

# %%
#install mish activation funciton for cuda
# %cd C:/Users/WMNL/scaled-yolov4_E7
# !git clone https://github.com/JunnYu/mish-cuda
# %cd mish-cuda
# !python setup.py build install
# Out:
# C:\Users\WMNL\scaled-yolov4_E7
# C:\Users\WMNL\scaled-yolov4_E7\mish-cuda
# fatal: destination path 'mish-cuda' already exists and is not an empty directory.
# running build
# running build_py
# running egg_info
# writing src\mish_cuda.egg-info\PKG-INFO
# writing dependency_links to src\mish_cuda.egg-info\dependency_links.txt
# writing requirements to src\mish_cuda.egg-info\requires.txt
# writing top-level names to src\mish_cuda.egg-info\top_level.txt
# reading manifest file 'src\mish_cuda.egg-info\SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'src\mish_cuda.egg-info\SOURCES.txt'
# running build_ext
# building 'mish_cuda._C' extension
# Emitting ninja build file C:\Users\WMNL\scaled-yolov4_E7\mish-cuda\build\temp.win-amd64-3.7\Release\build.ninja...
# Compiling objects...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# [1/3] cl /showIncludes /nologo /Ox /W3 /GL /DNDEBUG /MD /MD /wd4819 /wd4251 /wd4244 /wd4267 /wd4275 /wd4018 /wd4190 /EHsc -IC:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include -IC:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\torch\csrc\api\include -IC:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\TH -IC:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\THC "-IC:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v11.2\include" -IC:\Users\WMNL\anaconda3\envs\pytorch_E7\include -IC:\Users\WMNL\anaconda3\envs\pytorch_E7\include "-IC:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\shared" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\um" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\winrt" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\cppwinrt" -c C:\Users\WMNL\scaled-yolov4_E7\mish-cuda\csrc\cpu\mish_cpu.cpp /FoC:\Users\WMNL\scaled-yolov4_E7\mish-cuda\build\temp.win-amd64-3.7\Release\csrc/cpu/mish_cpu.obj -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_C -D_GLIBCXX_USE_CXX11_ABI=0 /std:c++14
# 注意: 包含檔案: C:\Users\WMNL\scaled-yolov4_E7\mish-cuda\csrc\cpu\mish_cpu.h
# 注意: 包含檔案:  C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\torch\csrc\api\include\torch/types.h
# 注意: 包含檔案:   C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/ATen.h
# 注意: 包含檔案:    C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/core/Allocator.h
# 注意: 包含檔案:     C:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt\stddef.h
# 注意: 包含檔案:      C:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt\corecrt.h
# 注意: 包含檔案:       C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\vcruntime.h
# 注意: 包含檔案:        C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\sal.h
# 注意: 包含檔案:         C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\concurrencysal.h
# 注意: 包含檔案:        C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\vadefs.h
# 注意: 包含檔案:     C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\memory
# 注意: 包含檔案:      C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\yvals_core.h
# 注意: 包含檔案:       C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\xkeycheck.h
# 注意: 包含檔案:      C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\exception
# 注意: 包含檔案:       C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\yvals.h
# 注意: 包含檔案:        C:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt\crtdbg.h
# 注意: 包含檔案:         C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\vcruntime_new_debug.h
# 注意: 包含檔案:          C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\vcruntime_new.h
# 注意: 包含檔案:        C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\crtdefs.h
# 注意: 包含檔案:        C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\use_ansi.h
# 注意: 包含檔案:       C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\type_traits
# 注意: 包含檔案:        C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\cstdint
# 注意: 包含檔案:         C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\stdint.h
# 注意: 包含檔案:        C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\xstddef
# 注意: 包含檔案:         C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\cstddef
# 注意: 包含檔案:          C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\xtr1common
# 注意: 包含檔案:         C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\cstdlib
# 注意: 包含檔案:          C:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt\math.h
# 注意: 包含檔案:           C:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt\corecrt_math.h
# 注意: 包含檔案:          C:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt\stdlib.h
# 注意: 包含檔案:           C:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt\corecrt_malloc.h
# 注意: 包含檔案:           C:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt\corecrt_search.h
# 注意: 包含檔案:           C:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt\corecrt_wstdlib.h
# 注意: 包含檔案:           C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\limits.h
# 注意: 包含檔案:         C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\initializer_list
# 注意: 包含檔案:       C:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt\malloc.h
# 注意: 包含檔案:       C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\vcruntime_exception.h
# 注意: 包含檔案:        C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\eh.h
# 注意: 包含檔案:         C:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt\corecrt_terminate.h
# 注意: 包含檔案:      C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\iosfwd
# 注意: 包含檔案:       C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\cstdio
# 注意: 包含檔案:        C:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt\stdio.h
# 注意: 包含檔案:         C:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt\corecrt_wstdio.h
# 注意: 包含檔案:          C:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt\corecrt_stdio_config.h
# 注意: 包含檔案:       C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\cstring
# 注意: 包含檔案:        C:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt\string.h
# 注意: 包含檔案:         C:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt\corecrt_memory.h
# 注意: 包含檔案:          C:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt\corecrt_memcpy_s.h
# 注意: 包含檔案:           C:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt\errno.h
# 注意: 包含檔案:           C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\vcruntime_string.h
# 注意: 包含檔案:         C:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt\corecrt_wstring.h
# 注意: 包含檔案:       C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\cwchar
# 注意: 包含檔案:        C:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt\wchar.h
# 注意: 包含檔案:         C:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt\corecrt_wconio.h
# 注意: 包含檔案:         C:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt\corecrt_wctype.h
# 注意: 包含檔案:         C:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt\corecrt_wdirect.h
# 注意: 包含檔案:         C:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt\corecrt_wio.h
# 注意: 包含檔案:          C:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt\corecrt_share.h
# 注意: 包含檔案:         C:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt\corecrt_wprocess.h
# 注意: 包含檔案:         C:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt\corecrt_wtime.h
# 注意: 包含檔案:         C:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt\sys/stat.h
# 注意: 包含檔案:          C:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt\sys/types.h
# 注意: 包含檔案:      C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\typeinfo
# 注意: 包含檔案:       C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\vcruntime_typeinfo.h
# 注意: 包含檔案:      C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\xmemory
# 注意: 包含檔案:       C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\limits
# 注意: 包含檔案:        C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\cfloat
# 注意: 包含檔案:         C:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt\float.h
# 注意: 包含檔案:        C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\climits
# 注意: 包含檔案:        C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\intrin0.h
# 注意: 包含檔案:         C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\intrin0.inl.h
# 注意: 包含檔案:        C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\isa_availability.h
# 注意: 包含檔案:       C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\new
# 注意: 包含檔案:       C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\xatomic.h
# 注意: 包含檔案:       C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\xutility
# 注意: 包含檔案:        C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\utility
# 注意: 包含檔案:     C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/core/Device.h
# 注意: 包含檔案:      C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/core/DeviceType.h
# 注意: 包含檔案:       C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/macros/Macros.h
# 注意: 包含檔案:        C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/macros/cmake_macros.h
# 注意: 包含檔案:        C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/macros/Export.h
# 注意: 包含檔案:        C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\sstream
# 注意: 包含檔案:         C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\istream
# 注意: 包含檔案:          C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\ostream
# 注意: 包含檔案:           C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\ios
# 注意: 包含檔案:            C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\xlocnum
# 注意: 包含檔案:             C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\cmath
# 注意: 包含檔案:             C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\iterator
# 注意: 包含檔案:             C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\streambuf
# 注意: 包含檔案:              C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\xiosbase
# 注意: 包含檔案:               C:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt\share.h
# 注意: 包含檔案:               C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\system_error
# 注意: 包含檔案:                C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\__msvc_system_error_abi.hpp
# 注意: 包含檔案:                C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\cerrno
# 注意: 包含檔案:                C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\stdexcept
# 注意: 包含檔案:                 C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\xstring
# 注意: 包含檔案:                C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\xcall_once.h
# 注意: 包含檔案:                C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\xerrc.h
# 注意: 包含檔案:                C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\atomic
# 注意: 包含檔案:                 C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\xthreads.h
# 注意: 包含檔案:                  C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\xtimec.h
# 注意: 包含檔案:                   C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\ctime
# 注意: 包含檔案:                    C:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt\time.h
# 注意: 包含檔案:               C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\xlocale
# 注意: 包含檔案:                C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\xfacet
# 注意: 包含檔案:                C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\xlocinfo
# 注意: 包含檔案:                 C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\xlocinfo.h
# 注意: 包含檔案:                  C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\cctype
# 注意: 包含檔案:                   C:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt\ctype.h
# 注意: 包含檔案:                  C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\clocale
# 注意: 包含檔案:                   C:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt\locale.h
# 注意: 包含檔案:         C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\string
# 注意: 包含檔案:       C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\functional
# 注意: 包含檔案:        C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\tuple
# 注意: 包含檔案:      C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/util/Exception.h
# 注意: 包含檔案:       C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/util/StringUtil.h
# 注意: 包含檔案:        C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/util/string_utils.h
# 注意: 包含檔案:        C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\vector
# 注意: 包含檔案:       C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/util/Deprecated.h
# 注意: 包含檔案:     C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/util/ThreadLocalDebugInfo.h
# 注意: 包含檔案:      C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\unordered_map
# 注意: 包含檔案:       C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\xhash
# 注意: 包含檔案:        C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\list
# 注意: 包含檔案:        C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\xbit_ops.h
# 注意: 包含檔案:     C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/util/UniqueVoidPtr.h
# 注意: 包含檔案:    C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/ATenGeneral.h
# 注意: 包含檔案:    C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/Context.h
# 注意: 包含檔案:     C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/Tensor.h
# 注意: 包含檔案:      C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/TensorBody.h
# 注意: 包含檔案:       C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/core/Layout.h
# 注意: 包含檔案:        C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/core/Backend.h
# 注意: 包含檔案:         C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/core/DispatchKey.h
# 注意: 包含檔案:          C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\iostream
# 注意: 包含檔案:          C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/util/ArrayRef.h
# 注意: 包含檔案:           C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/util/SmallVector.h
# 注意: 包含檔案:            C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/util/AlignOf.h
# 注意: 包含檔案:            C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\algorithm
# 注意: 包含檔案:            C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\cassert
# 注意: 包含檔案:             C:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt\assert.h
# 注意: 包含檔案:           C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/util/C++17.h
# 注意: 包含檔案:           C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\array
# 注意: 包含檔案:         C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/core/DispatchKeySet.h
# 注意: 包含檔案:          C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/util/llvmMathExtras.h
# 注意: 包含檔案:           C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\cassert
# 注意: 包含檔案:            C:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt\assert.h
# 注意: 包含檔案:       C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/core/MemoryFormat.h
# 注意: 包含檔案:       C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/core/QScheme.h
# 注意: 包含檔案:       C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/core/Scalar.h
# 注意: 包含檔案:        C:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt\assert.h
# 注意: 包含檔案:        C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/core/ScalarType.h
# 注意: 包含檔案:         C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/util/complex.h
# 注意: 包含檔案:          C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\complex
# 注意: 包含檔案:           C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\ymath.h
# 注意: 包含檔案:           C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\emmintrin.h
# 注意: 包含檔案:            C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\xmmintrin.h
# 注意: 包含檔案:             C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\mmintrin.h
# 注意: 包含檔案:          C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/util/complex_math.h
# 注意: 包含檔案:          C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/util/complex_utils.h
# 注意: 包含檔案:         C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/util/Half.h
# 注意: 包含檔案:          C:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt\math.h
# 注意: 包含檔案:          C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\intrin.h
# 注意: 包含檔案:           C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\setjmp.h
# 注意: 包含檔案:           C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\immintrin.h
# 注意: 包含檔案:            C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\wmmintrin.h
# 注意: 包含檔案:             C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\nmmintrin.h
# 注意: 包含檔案:              C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\smmintrin.h
# 注意: 包含檔案:               C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\tmmintrin.h
# 注意: 包含檔案:                C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\pmmintrin.h
# 注意: 包含檔案:            C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\zmmintrin.h
# 注意: 包含檔案:           C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\ammintrin.h
# 注意: 包含檔案:          C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/util/Half-inl.h
# 注意: 包含檔案:         C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/util/BFloat16.h
# 注意: 包含檔案:          C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/util/BFloat16-inl.h
# 注意: 包含檔案:         C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/util/Optional.h
# 注意: 包含檔案:          C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/util/in_place.h
# 注意: 包含檔案:          C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\cassert
# 注意: 包含檔案:           C:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt\assert.h
# 注意: 包含檔案:         C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/util/typeid.h
# 注意: 包含檔案:          C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\cassert
# 注意: 包含檔案:           C:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt\assert.h
# 注意: 包含檔案:          C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\mutex
# 注意: 包含檔案:           C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\chrono
# 注意: 包含檔案:            C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\ratio
# 注意: 包含檔案:           C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\thread
# 注意: 包含檔案:            C:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt\process.h
# 注意: 包含檔案:             C:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt\corecrt_startup.h
# 注意: 包含檔案:              C:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt\math.h
# 注意: 包含檔案:              C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\vcruntime_startup.h
# 注意: 包含檔案:          C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\unordered_set
# 注意: 包含檔案:          C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/util/Backtrace.h
# 注意: 包含檔案:          C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/util/IdWrapper.h
# 注意: 包含檔案:          C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/util/Type.h
# 注意: 包含檔案:          C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/util/TypeTraits.h
# 注意: 包含檔案:          C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/util/TypeIndex.h
# 注意: 包含檔案:           C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/util/ConstexprCrc.h
# 注意: 包含檔案:            C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/util/string_view.h
# 注意: 包含檔案:             C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/util/reverse_iterator.h
# 注意: 包含檔案:           C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\cinttypes
# 注意: 包含檔案:            C:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt\inttypes.h
# 注意: 包含檔案:          C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/util/qint32.h
# 注意: 包含檔案:          C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/util/qint8.h
# 注意: 包含檔案:          C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/util/quint8.h
# 注意: 包含檔案:          C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/util/flat_hash_map.h
# 注意: 包含檔案:        C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/util/TypeCast.h
# 注意: 包含檔案:       C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/core/Storage.h
# 注意: 包含檔案:        C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/core/StorageImpl.h
# 注意: 包含檔案:         C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/util/intrusive_ptr.h
# 注意: 包含檔案:       C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/TensorAccessor.h
# 注意: 包含檔案:       C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/core/TensorImpl.h
# 注意: 包含檔案:        C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\numeric
# 注意: 包含檔案:        C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/core/TensorOptions.h
# 注意: 包含檔案:         C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/core/DefaultDtype.h
# 注意: 包含檔案:        C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/core/impl/LocalDispatchKeySet.h
# 注意: 包含檔案:         C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/util/Flags.h
# 注意: 包含檔案:          C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/util/Registry.h
# 注意: 包含檔案:        C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/core/CopyBytes.h
# 注意: 包含檔案:        C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/util/Logging.h
# 注意: 包含檔案:         C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/util/logging_is_not_google_glog.h
# 注意: 包含檔案:          C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\fstream
# 注意: 包含檔案:          C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\iomanip
# 注意: 包含檔案:           C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\xlocmon
# 注意: 包含檔案:           C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\xloctime
# 注意: 包含檔案:          C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\map
# 注意: 包含檔案:           C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\xtree
# 注意: 包含檔案:          C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\set
# 注意: 包含檔案:        C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/util/python_stub.h
# 注意: 包含檔案:       C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/core/UndefinedTensorImpl.h
# 注意: 包含檔案:       C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/DeprecatedTypePropertiesRegistry.h
# 注意: 包含檔案:       C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/DeprecatedTypeProperties.h
# 注意: 包含檔案:        C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/Generator.h
# 注意: 包含檔案:         C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\deque
# 注意: 包含檔案:         C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/core/GeneratorImpl.h
# 注意: 包含檔案:       C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/NamedTensor.h
# 注意: 包含檔案:        C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/Dimname.h
# 注意: 包含檔案:         C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/interned_strings.h
# 注意: 包含檔案:          C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/aten_interned_strings.h
# 注意: 包含檔案:       C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/QuantizerBase.h
# 注意: 包含檔案:       C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\torch/csrc/WindowsTorchApiMacro.h
# 注意: 包含檔案:     C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/Utils.h
# 注意: 包含檔案:      C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/Formatting.h
# 注意: 包含檔案:       C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/Formatting.h
# 注意: 包含檔案:        C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/Tensor.h
# 注意: 包含檔案:     C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/CPUGeneratorImpl.h
# 注意: 包含檔案:      C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/MT19937RNGEngine.h
# 注意: 包含檔案:       C:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt\math.h
# 注意: 包含檔案:        C:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt\corecrt_math_defines.h
# 注意: 包含檔案:     C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/LegacyTypeDispatch.h
# 注意: 包含檔案:     C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/detail/CUDAHooksInterface.h
# 注意: 包含檔案:     C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/detail/HIPHooksInterface.h
# 注意: 包含檔案:     C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/core/impl/DeviceGuardImplInterface.h
# 注意: 包含檔案:      C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/core/Stream.h
# 注意: 包含檔案:     C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/core/QEngine.h
# 注意: 包含檔案:    C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/Device.h
# 注意: 包含檔案:    C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/DeviceGuard.h
# 注意: 包含檔案:     C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/core/DeviceGuard.h
# 注意: 包含檔案:      C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/core/impl/InlineDeviceGuard.h
# 注意: 包含檔案:       C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/core/impl/VirtualGuardImpl.h
# 注意: 包含檔案:    C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/DimVector.h
# 注意: 包含檔案:     C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/DimVector.h
# 注意: 包含檔案:    C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/Dispatch.h
# 注意: 包含檔案:    C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/DynamicLibrary.h
# 注意: 包含檔案:    C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/Formatting.h
# 注意: 包含檔案:    C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/Functions.h
# 注意: 包含檔案:     C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/NativeFunctions.h
# 注意: 包含檔案:      C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/Reduction.h
# 注意: 包含檔案:     C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/TensorUtils.h
# 注意: 包含檔案:      C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/TensorGeometry.h
# 注意: 包含檔案:       C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/WrapDimUtils.h
# 注意: 包含檔案:        C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/core/WrapDimMinimal.h
# 注意: 包含檔案:     C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/TracerMode.h
# 注意: 包含檔案:     C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/op_registration/hacky_wrapper_for_legacy_signatures.h
# 注意: 包含檔案:      C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/util/Metaprogramming.h
# 注意: 包含檔案:       C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/util/TypeList.h
# 注意: 包含檔案:       C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/util/Array.h
# 注意: 包含檔案:      C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/core/CompileTimeFunctionPointer.h
# 注意: 包含檔案:    C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/NamedTensor.h
# 注意: 包含檔案:    C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/ScalarOps.h
# 注意: 包含檔案:    C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/TensorIndexing.h
# 注意: 包含檔案:     C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/ExpandUtils.h
# 注意: 包含檔案:    C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/TensorOperators.h
# 注意: 包含檔案:    C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/Version.h
# 注意: 包含檔案:    C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/Scalar.h
# 注意: 包含檔案:    C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/UnsafeFromTH.h
# 注意: 包含檔案:    C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/ivalue.h
# 注意: 包含檔案:     C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/blob.h
# 注意: 包含檔案:     C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\typeindex
# 注意: 包含檔案:     C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/ivalue_inl.h
# 注意: 包含檔案:      C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\condition_variable
# 注意: 包含檔案:      C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/functional.h
# 注意: 包含檔案:      C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/Dict.h
# 注意: 包含檔案:       C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/util/order_preserving_flat_hash_map.h
# 注意: 包含檔案:       C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/Dict_inl.h
# 注意: 包含檔案:      C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/List.h
# 注意: 包含檔案:       C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/List_inl.h
# 注意: 包含檔案:        C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/jit_type.h
# 注意: 包含檔案:         C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/qualified_name.h
# 注意: 包含檔案:      C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/rref_interface.h
# C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/ivalue_inl.h(389): warning C4101: 'e': 未參考的區域變數
# 注意: 包含檔案:   C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\torch/csrc/autograd/generated/variable_factories.h
# 注意: 包含檔案:    C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/grad_mode.h
# 注意: 包含檔案:    C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\torch/csrc/api/include/torch/detail/TensorDataContainer.h
# 注意: 包含檔案:    C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\torch/csrc/autograd/variable.h
# 注意: 包含檔案:     C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\torch/csrc/utils/python_stub.h
# 注意: 包含檔案:     C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\torch/csrc/autograd/edge.h
# 注意: 包含檔案:      C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/util/hash.h
# 注意: 包含檔案:     C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\torch/csrc/autograd/function_hook.h
# 注意: 包含檔案:     C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\torch/csrc/autograd/cpp_hook.h
# 注意: 包含檔案:     C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/NamedTensorUtils.h
# 注意: 包含檔案:      C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/NamedTensor.h
# 注意: 包含檔案:      C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/TensorNames.h
# 注意: 包含檔案:    C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\torch/csrc/jit/frontend/tracer.h
# 注意: 包含檔案:     C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/stack.h
# 注意: 包含檔案:     C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\torch/csrc/jit/api/object.h
# 注意: 包含檔案:      C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\torch/csrc/jit/api/method.h
# 注意: 包含檔案:       C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/function.h
# 注意: 包含檔案:        C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/function_schema.h
# 注意: 包含檔案:         C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/alias_info.h
# 注意: 包含檔案:         C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/operator_name.h
# 注意: 包含檔案:         C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/dispatch/OperatorOptions.h
# 注意: 包含檔案:         C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/function_schema_inl.h
# 注意: 包含檔案:       C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\torch/csrc/jit/api/function_impl.h
# 注意: 包含檔案:        C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\torch/csrc/jit/ir/ir.h
# 注意: 包含檔案:         C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\torch/csrc/jit/ir/attributes.h
# 注意: 包含檔案:         C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\torch/csrc/jit/ir/graph_node_list.h
# 注意: 包含檔案:         C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\torch/csrc/jit/ir/named_value.h
# 注意: 包含檔案:          C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\torch/csrc/jit/frontend/source_range.h
# 注意: 包含檔案:          C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\torch/csrc/jit/ir/constants.h
# 注意: 包含檔案:           C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\torch/csrc/jit/ir/scope.h
# 注意: 包含檔案:          C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\torch/csrc/utils/variadic.h
# 注意: 包含檔案:           C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/Variadic.h
# 注意: 包含檔案:         C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\torch/csrc/jit/runtime/operator.h
# 注意: 包含檔案:          C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/dispatch/Dispatcher.h
# 注意: 包含檔案:           C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/SequenceNumber.h
# 注意: 包含檔案:           C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/boxing/KernelFunction.h
# 注意: 包含檔案:            C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/boxing/KernelFunction_impl.h
# 注意: 包含檔案:             C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/boxing/impl/boxing.h
# 注意: 包含檔案:             C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/boxing/impl/make_boxed_from_unboxed_functor.h
# 注意: 包含檔案:             C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/boxing/impl/WrapFunctionIntoFunctor.h
# 注意: 包含檔案:             C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/boxing/impl/WrapFunctionIntoRuntimeFunctor.h
# 注意: 包含檔案:           C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/dispatch/OperatorEntry.h
# 注意: 包含檔案:            C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/util/either.h
# 注意: 包含檔案:            C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/dispatch/DispatchKeyExtractor.h
# 注意: 包含檔案:             C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/util/Bitset.h
# 注意: 包含檔案:            C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/dispatch/CppSignature.h
# 注意: 包含檔案:            C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/dispatch/RegistrationHandleRAII.h
# 注意: 包含檔案:           C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/record_function.h
# 注意: 包含檔案:           C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/util/LeftRight.h
# 注意: 包含檔案:          C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/op_registration/op_whitelist.h
# 注意: 包含檔案:          C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\torch/csrc/jit/frontend/function_schema_parser.h
# 注意: 包含檔案:           C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/Macros.h
# 注意: 包含檔案:          C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\torch/csrc/jit/runtime/operator_options.h
# 注意: 包含檔案:          C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\torch/library.h
# 注意: 包含檔案:           C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/op_registration/infer_schema.h
# 注意: 包含檔案:           C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/op_registration/op_registration.h
# 注意: 包含檔案:            C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/ATenOpList.h
# 注意: 包含檔案:           C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\torch/custom_class.h
# 注意: 包含檔案:            C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/core/builtin_function.h
# 注意: 包含檔案:            C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\torch/custom_class_detail.h
# 注意: 包含檔案:         C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\torch/csrc/utils/disallow_copy.h
# 注意: 包含檔案:        C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\torch/csrc/jit/runtime/graph_executor.h
# 注意: 包含檔案:         C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\torch/csrc/jit/python/update_graph_executor_opt.h
# 注意: 包含檔案:         C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\torch/csrc/jit/runtime/argument_spec.h
# 注意: 包含檔案:         C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\torch/csrc/jit/runtime/interpreter.h
# 注意: 包含檔案:          C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/ThreadLocalState.h
# 注意: 包含檔案:         C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\torch/csrc/jit/runtime/variable_tensor_list.h
# 注意: 包含檔案:        C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\torch/csrc/utils/memory.h
# 注意: 包含檔案: C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/CPUApplyUtils.h
# 注意: 包含檔案:  C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/Parallel.h
# 注意: 包含檔案:   C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/Config.h
# 注意: 包含檔案:   C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\ATen/ParallelOpenMP.h
# [2/3] cl /showIncludes /nologo /Ox /W3 /GL /DNDEBUG /MD /MD /wd4819 /wd4251 /wd4244 /wd4267 /wd4275 /wd4018 /wd4190 /EHsc -IC:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include -IC:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\torch\csrc\api\include -IC:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\TH -IC:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\THC "-IC:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v11.2\include" -IC:\Users\WMNL\anaconda3\envs\pytorch_E7\include -IC:\Users\WMNL\anaconda3\envs\pytorch_E7\include "-IC:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\shared" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\um" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\winrt" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\cppwinrt" -c C:\Users\WMNL\scaled-yolov4_E7\mish-cuda\csrc\cuda\mish_cuda.cpp /FoC:\Users\WMNL\scaled-yolov4_E7\mish-cuda\build\temp.win-amd64-3.7\Release\csrc/cuda/mish_cuda.obj -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_C -D_GLIBCXX_USE_CXX11_ABI=0 /std:c++14
# 注意: 包含檔案: C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\torch/extension.h
# 注意: 包含檔案:  C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\torch\csrc\api\include\torch/all.h
# 注意: 包含檔案:   C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\torch\csrc\api\include\torch/cuda.h
# 注意: 包含檔案:    C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\torch/csrc/WindowsTorchApiMacro.h
# 注意: 包含檔案:     C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/macros/Export.h
# 注意: 包含檔案:      C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\include\c10/macros/cmake_macros.h
# 注意: 包含檔案:    C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\cstdint
# 注意: 包含檔案:     C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\yvals_core.h
# 注意: 包含檔案:      C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\vcruntime.h
# 注意: 包含檔案:       C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\sal.h
# 注意: 包含檔案:        C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\concurrencysal.h
# 注意: 包含檔案:       C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\vadefs.h
# 注意: 包含檔案:      C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\include\xkeycheck.h
# ...
# ptxas warning : Value of threads per SM for entry _ZN2at4cuda70_GLOBAL__N__46_tmpxft_000022b0_00000000_8_mish_kernel_cpp1_ii_a38e28d521kernelPointwiseApply2IZN6kernel12mish_forwardIN3c104HalfEEEvRNS_6TensorERKS7_EUlRS6_RKS6_E_S6_S6_yLin1ELin1ELi1EEEvNS0_6detail10TensorInfoIT0_T2_EENSG_IT1_SI_EESI_T_ is out of range. .minnctapersm will be ignored
# ptxas warning : Value of threads per SM for entry _ZN2at4cuda70_GLOBAL__N__46_tmpxft_000022b0_00000000_8_mish_kernel_cpp1_ii_a38e28d521kernelPointwiseApply2IZN6kernel12mish_forwardIN3c104HalfEEEvRNS_6TensorERKS7_EUlRS6_RKS6_E_S6_S6_yLi1ELi1ELi1EEEvNS0_6detail10TensorInfoIT0_T2_EENSG_IT1_SI_EESI_T_ is out of range. .minnctapersm will be ignored
# ptxas warning : Value of threads per SM for entry _ZN2at4cuda70_GLOBAL__N__46_tmpxft_000022b0_00000000_8_mish_kernel_cpp1_ii_a38e28d521kernelPointwiseApply2IZN6kernel12mish_forwardIN3c104HalfEEEvRNS_6TensorERKS7_EUlRS6_RKS6_E_S6_S6_jLin1ELin1ELi1EEEvNS0_6detail10TensorInfoIT0_T2_EENSG_IT1_SI_EESI_T_ is out of range. .minnctapersm will be ignored
# ptxas warning : Value of threads per SM for entry _ZN2at4cuda70_GLOBAL__N__46_tmpxft_000022b0_00000000_8_mish_kernel_cpp1_ii_a38e28d521kernelPointwiseApply2IZN6kernel12mish_forwardIN3c104HalfEEEvRNS_6TensorERKS7_EUlRS6_RKS6_E_S6_S6_jLin1ELi2ELi1EEEvNS0_6detail10TensorInfoIT0_T2_EENSG_IT1_SI_EESI_T_ is out of range. .minnctapersm will be ignored
# ptxas warning : Value of threads per SM for entry _ZN2at4cuda70_GLOBAL__N__46_tmpxft_000022b0_00000000_8_mish_kernel_cpp1_ii_a38e28d521kernelPointwiseApply2IZN6kernel12mish_forwardIN3c104HalfEEEvRNS_6TensorERKS7_EUlRS6_RKS6_E_S6_S6_jLin1ELi1ELi1EEEvNS0_6detail10TensorInfoIT0_T2_EENSG_IT1_SI_EESI_T_ is out of range. .minnctapersm will be ignored
# ptxas warning : Value of threads per SM for entry _ZN2at4cuda70_GLOBAL__N__46_tmpxft_000022b0_00000000_8_mish_kernel_cpp1_ii_a38e28d521kernelPointwiseApply2IZN6kernel12mish_forwardIN3c104HalfEEEvRNS_6TensorERKS7_EUlRS6_RKS6_E_S6_S6_jLi2ELin1ELi1EEEvNS0_6detail10TensorInfoIT0_T2_EENSG_IT1_SI_EESI_T_ is out of range. .minnctapersm will be ignored
# ptxas warning : Value of threads per SM for entry _ZN2at4cuda70_GLOBAL__N__46_tmpxft_000022b0_00000000_8_mish_kernel_cpp1_ii_a38e28d521kernelPointwiseApply2IZN6kernel12mish_forwardIN3c104HalfEEEvRNS_6TensorERKS7_EUlRS6_RKS6_E_S6_S6_jLi2ELi2ELi1EEEvNS0_6detail10TensorInfoIT0_T2_EENSG_IT1_SI_EESI_T_ is out of range. .minnctapersm will be ignored
# ptxas warning : Value of threads per SM for entry _ZN2at4cuda70_GLOBAL__N__46_tmpxft_000022b0_00000000_8_mish_kernel_cpp1_ii_a38e28d521kernelPointwiseApply2IZN6kernel12mish_forwardIN3c104HalfEEEvRNS_6TensorERKS7_EUlRS6_RKS6_E_S6_S6_jLi2ELi1ELi1EEEvNS0_6detail10TensorInfoIT0_T2_EENSG_IT1_SI_EESI_T_ is out of range. .minnctapersm will be ignored
# ptxas warning : Value of threads per SM for entry _ZN2at4cuda70_GLOBAL__N__46_tmpxft_000022b0_00000000_8_mish_kernel_cpp1_ii_a38e28d521kernelPointwiseApply2IZN6kernel12mish_forwardIN3c104HalfEEEvRNS_6TensorERKS7_EUlRS6_RKS6_E_S6_S6_jLi1ELin1ELi1EEEvNS0_6detail10TensorInfoIT0_T2_EENSG_IT1_SI_EESI_T_ is out of range. .minnctapersm will be ignored
# ptxas warning : Value of threads per SM for entry _ZN2at4cuda70_GLOBAL__N__46_tmpxft_000022b0_00000000_8_mish_kernel_cpp1_ii_a38e28d521kernelPointwiseApply2IZN6kernel12mish_forwardIN3c104HalfEEEvRNS_6TensorERKS7_EUlRS6_RKS6_E_S6_S6_jLi1ELi2ELi1EEEvNS0_6detail10TensorInfoIT0_T2_EENSG_IT1_SI_EESI_T_ is out of range. .minnctapersm will be ignored
# ptxas warning : Value of threads per SM for entry _ZN2at4cuda70_GLOBAL__N__46_tmpxft_000022b0_00000000_8_mish_kernel_cpp1_ii_a38e28d521kernelPointwiseApply2IZN6kernel12mish_forwardIN3c104HalfEEEvRNS_6TensorERKS7_EUlRS6_RKS6_E_S6_S6_jLi1ELi1ELi1EEEvNS0_6detail10TensorInfoIT0_T2_EENSG_IT1_SI_EESI_T_ is out of range. .minnctapersm will be ignored
# ptxas warning : Value of threads per SM for entry _ZN2at4cuda70_GLOBAL__N__46_tmpxft_000022b0_00000000_8_mish_kernel_cpp1_ii_a38e28d521kernelPointwiseApply2IZN6kernel12mish_forwardIfEEvRNS_6TensorERKS5_EUlRfRKfE_ffyLin1ELin1ELi1EEEvNS0_6detail10TensorInfoIT0_T2_EENSE_IT1_SG_EESG_T_ is out of range. .minnctapersm will be ignored
# ptxas warning : Value of threads per SM for entry _ZN2at4cuda70_GLOBAL__N__46_tmpxft_000022b0_00000000_8_mish_kernel_cpp1_ii_a38e28d521kernelPointwiseApply2IZN6kernel12mish_forwardIfEEvRNS_6TensorERKS5_EUlRfRKfE_ffyLi1ELi1ELi1EEEvNS0_6detail10TensorInfoIT0_T2_EENSE_IT1_SG_EESG_T_ is out of range. .minnctapersm will be ignored
# ptxas warning : Value of threads per SM for entry _ZN2at4cuda70_GLOBAL__N__46_tmpxft_000022b0_00000000_8_mish_kernel_cpp1_ii_a38e28d521kernelPointwiseApply2IZN6kernel12mish_forwardIfEEvRNS_6TensorERKS5_EUlRfRKfE_ffjLin1ELin1ELi1EEEvNS0_6detail10TensorInfoIT0_T2_EENSE_IT1_SG_EESG_T_ is out of range. .minnctapersm will be ignored
# ptxas warning : Value of threads per SM for entry _ZN2at4cuda70_GLOBAL__N__46_tmpxft_000022b0_00000000_8_mish_kernel_cpp1_ii_a38e28d521kernelPointwiseApply2IZN6kernel12mish_forwardIfEEvRNS_6TensorERKS5_EUlRfRKfE_ffjLin1ELi2ELi1EEEvNS0_6detail10TensorInfoIT0_T2_EENSE_IT1_SG_EESG_T_ is out of range. .minnctapersm will be ignored
# ptxas warning : Value of threads per SM for entry _ZN2at4cuda70_GLOBAL__N__46_tmpxft_000022b0_00000000_8_mish_kernel_cpp1_ii_a38e28d521kernelPointwiseApply2IZN6kernel12mish_forwardIfEEvRNS_6TensorERKS5_EUlRfRKfE_ffjLin1ELi1ELi1EEEvNS0_6detail10TensorInfoIT0_T2_EENSE_IT1_SG_EESG_T_ is out of range. .minnctapersm will be ignored
# ptxas warning : Value of threads per SM for entry _ZN2at4cuda70_GLOBAL__N__46_tmpxft_000022b0_00000000_8_mish_kernel_cpp1_ii_a38e28d521kernelPointwiseApply2IZN6kernel12mish_forwardIfEEvRNS_6TensorERKS5_EUlRfRKfE_ffjLi2ELin1ELi1EEEvNS0_6detail10TensorInfoIT0_T2_EENSE_IT1_SG_EESG_T_ is out of range. .minnctapersm will be ignored
# ptxas warning : Value of threads per SM for entry _ZN2at4cuda70_GLOBAL__N__46_tmpxft_000022b0_00000000_8_mish_kernel_cpp1_ii_a38e28d521kernelPointwiseApply2IZN6kernel12mish_forwardIfEEvRNS_6TensorERKS5_EUlRfRKfE_ffjLi2ELi2ELi1EEEvNS0_6detail10TensorInfoIT0_T2_EENSE_IT1_SG_EESG_T_ is out of range. .minnctapersm will be ignored
# ptxas warning : Value of threads per SM for entry _ZN2at4cuda70_GLOBAL__N__46_tmpxft_000022b0_00000000_8_mish_kernel_cpp1_ii_a38e28d521kernelPointwiseApply2IZN6kernel12mish_forwardIfEEvRNS_6TensorERKS5_EUlRfRKfE_ffjLi2ELi1ELi1EEEvNS0_6detail10TensorInfoIT0_T2_EENSE_IT1_SG_EESG_T_ is out of range. .minnctapersm will be ignored
# ptxas warning : Value of threads per SM for entry _ZN2at4cuda70_GLOBAL__N__46_tmpxft_000022b0_00000000_8_mish_kernel_cpp1_ii_a38e28d521kernelPointwiseApply2IZN6kernel12mish_forwardIfEEvRNS_6TensorERKS5_EUlRfRKfE_ffjLi1ELin1ELi1EEEvNS0_6detail10TensorInfoIT0_T2_EENSE_IT1_SG_EESG_T_ is out of range. .minnctapersm will be ignored
# ptxas warning : Value of threads per SM for entry _ZN2at4cuda70_GLOBAL__N__46_tmpxft_000022b0_00000000_8_mish_kernel_cpp1_ii_a38e28d521kernelPointwiseApply2IZN6kernel12mish_forwardIfEEvRNS_6TensorERKS5_EUlRfRKfE_ffjLi1ELi2ELi1EEEvNS0_6detail10TensorInfoIT0_T2_EENSE_IT1_SG_EESG_T_ is out of range. .minnctapersm will be ignored
# ptxas warning : Value of threads per SM for entry _ZN2at4cuda70_GLOBAL__N__46_tmpxft_000022b0_00000000_8_mish_kernel_cpp1_ii_a38e28d521kernelPointwiseApply2IZN6kernel12mish_forwardIfEEvRNS_6TensorERKS5_EUlRfRKfE_ffjLi1ELi1ELi1EEEvNS0_6detail10TensorInfoIT0_T2_EENSE_IT1_SG_EESG_T_ is out of range. .minnctapersm will be ignored
# ptxas warning : Value of threads per SM for entry _ZN2at4cuda70_GLOBAL__N__46_tmpxft_000022b0_00000000_8_mish_kernel_cpp1_ii_a38e28d521kernelPointwiseApply2IZN6kernel12mish_forwardIdEEvRNS_6TensorERKS5_EUlRdRKdE_ddyLin1ELin1ELi1EEEvNS0_6detail10TensorInfoIT0_T2_EENSE_IT1_SG_EESG_T_ is out of range. .minnctapersm will be ignored
# ptxas warning : Value of threads per SM for entry _ZN2at4cuda70_GLOBAL__N__46_tmpxft_000022b0_00000000_8_mish_kernel_cpp1_ii_a38e28d521kernelPointwiseApply2IZN6kernel12mish_forwardIdEEvRNS_6TensorERKS5_EUlRdRKdE_ddyLi1ELi1ELi1EEEvNS0_6detail10TensorInfoIT0_T2_EENSE_IT1_SG_EESG_T_ is out of range. .minnctapersm will be ignored
# ptxas warning : Value of threads per SM for entry _ZN2at4cuda70_GLOBAL__N__46_tmpxft_000022b0_00000000_8_mish_kernel_cpp1_ii_a38e28d521kernelPointwiseApply2IZN6kernel12mish_forwardIdEEvRNS_6TensorERKS5_EUlRdRKdE_ddjLin1ELin1ELi1EEEvNS0_6detail10TensorInfoIT0_T2_EENSE_IT1_SG_EESG_T_ is out of range. .minnctapersm will be ignored
# ptxas warning : Value of threads per SM for entry _ZN2at4cuda70_GLOBAL__N__46_tmpxft_000022b0_00000000_8_mish_kernel_cpp1_ii_a38e28d521kernelPointwiseApply2IZN6kernel12mish_forwardIdEEvRNS_6TensorERKS5_EUlRdRKdE_ddjLin1ELi2ELi1EEEvNS0_6detail10TensorInfoIT0_T2_EENSE_IT1_SG_EESG_T_ is out of range. .minnctapersm will be ignored
# ptxas warning : Value of threads per SM for entry _ZN2at4cuda70_GLOBAL__N__46_tmpxft_000022b0_00000000_8_mish_kernel_cpp1_ii_a38e28d521kernelPointwiseApply2IZN6kernel12mish_forwardIdEEvRNS_6TensorERKS5_EUlRdRKdE_ddjLin1ELi1ELi1EEEvNS0_6detail10TensorInfoIT0_T2_EENSE_IT1_SG_EESG_T_ is out of range. .minnctapersm will be ignored
# ptxas warning : Value of threads per SM for entry _ZN2at4cuda70_GLOBAL__N__46_tmpxft_000022b0_00000000_8_mish_kernel_cpp1_ii_a38e28d521kernelPointwiseApply2IZN6kernel12mish_forwardIdEEvRNS_6TensorERKS5_EUlRdRKdE_ddjLi2ELin1ELi1EEEvNS0_6detail10TensorInfoIT0_T2_EENSE_IT1_SG_EESG_T_ is out of range. .minnctapersm will be ignored
# ptxas warning : Value of threads per SM for entry _ZN2at4cuda70_GLOBAL__N__46_tmpxft_000022b0_00000000_8_mish_kernel_cpp1_ii_a38e28d521kernelPointwiseApply2IZN6kernel12mish_forwardIdEEvRNS_6TensorERKS5_EUlRdRKdE_ddjLi2ELi2ELi1EEEvNS0_6detail10TensorInfoIT0_T2_EENSE_IT1_SG_EESG_T_ is out of range. .minnctapersm will be ignored
# ptxas warning : Value of threads per SM for entry _ZN2at4cuda70_GLOBAL__N__46_tmpxft_000022b0_00000000_8_mish_kernel_cpp1_ii_a38e28d521kernelPointwiseApply2IZN6kernel12mish_forwardIdEEvRNS_6TensorERKS5_EUlRdRKdE_ddjLi2ELi1ELi1EEEvNS0_6detail10TensorInfoIT0_T2_EENSE_IT1_SG_EESG_T_ is out of range. .minnctapersm will be ignored
# ptxas warning : Value of threads per SM for entry _ZN2at4cuda70_GLOBAL__N__46_tmpxft_000022b0_00000000_8_mish_kernel_cpp1_ii_a38e28d521kernelPointwiseApply2IZN6kernel12mish_forwardIdEEvRNS_6TensorERKS5_EUlRdRKdE_ddjLi1ELin1ELi1EEEvNS0_6detail10TensorInfoIT0_T2_EENSE_IT1_SG_EESG_T_ is out of range. .minnctapersm will be ignored
# ptxas warning : Value of threads per SM for entry _ZN2at4cuda70_GLOBAL__N__46_tmpxft_000022b0_00000000_8_mish_kernel_cpp1_ii_a38e28d521kernelPointwiseApply2IZN6kernel12mish_forwardIdEEvRNS_6TensorERKS5_EUlRdRKdE_ddjLi1ELi2ELi1EEEvNS0_6detail10TensorInfoIT0_T2_EENSE_IT1_SG_EESG_T_ is out of range. .minnctapersm will be ignored
# ptxas warning : Value of threads per SM for entry _ZN2at4cuda70_GLOBAL__N__46_tmpxft_000022b0_00000000_8_mish_kernel_cpp1_ii_a38e28d521kernelPointwiseApply2IZN6kernel12mish_forwardIdEEvRNS_6TensorERKS5_EUlRdRKdE_ddjLi1ELi1ELi1EEEvNS0_6detail10TensorInfoIT0_T2_EENSE_IT1_SG_EESG_T_ is out of range. .minnctapersm will be ignored
# C:/Users/WMNL/anaconda3/envs/pytorch_E7/lib/site-packages/torch/include\ATen/core/boxing/impl/boxing.h(100): warning: integer conversion resulted in a change of sign
#
# C:/Users/WMNL/anaconda3/envs/pytorch_E7/lib/site-packages/torch/include\ATen/core/op_registration/op_whitelist.h(39): warning: integer conversion resulted in a change of sign
#
# mish_kernel.cu
# C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\bin\HostX86\x64\link.exe /nologo /INCREMENTAL:NO /LTCG /DLL /MANIFEST:EMBED,ID=2 /MANIFESTUAC:NO /LIBPATH:C:\Users\WMNL\anaconda3\envs\pytorch_E7\lib\site-packages\torch\lib "/LIBPATH:C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v11.2\lib/x64" /LIBPATH:C:\Users\WMNL\anaconda3\envs\pytorch_E7\libs /LIBPATH:C:\Users\WMNL\anaconda3\envs\pytorch_E7\PCbuild\amd64 "/LIBPATH:C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.29.30133\lib\x64" "/LIBPATH:C:\Program Files (x86)\Windows Kits\10\lib\10.0.19041.0\ucrt\x64" "/LIBPATH:C:\Program Files (x86)\Windows Kits\10\lib\10.0.19041.0\um\x64" c10.lib torch.lib torch_cpu.lib torch_python.lib cudart.lib c10_cuda.lib torch_cuda.lib /EXPORT:PyInit__C C:\Users\WMNL\scaled-yolov4_E7\mish-cuda\build\temp.win-amd64-3.7\Release\csrc/cpu/mish_cpu.obj C:\Users\WMNL\scaled-yolov4_E7\mish-cuda\build\temp.win-amd64-3.7\Release\csrc/cuda/mish_cuda.obj C:\Users\WMNL\scaled-yolov4_E7\mish-cuda\build\temp.win-amd64-3.7\Release\csrc/cuda/mish_kernel.obj /OUT:build\lib.win-amd64-3.7\mish_cuda\_C.cp37-win_amd64.pyd /IMPLIB:C:\Users\WMNL\scaled-yolov4_E7\mish-cuda\build\temp.win-amd64-3.7\Release\csrc/cpu\_C.cp37-win_amd64.lib
#    正在建立程式庫 C:\Users\WMNL\scaled-yolov4_E7\mish-cuda\build\temp.win-amd64-3.7\Release\csrc/cpu\_C.cp37-win_amd64.lib 和物件 C:\Users\WMNL\scaled-yolov4_E7\mish-cuda\build\temp.win-amd64-3.7\Release\csrc/cpu\_C.cp37-win_amd64.exp
# 正在產生程式碼
# 已完成程式碼產生
# running install
# running bdist_egg
# installing library code to build\bdist.win-amd64\egg
# running install_lib
# creating build\bdist.win-amd64
# creating build\bdist.win-amd64\egg
# creating build\bdist.win-amd64\egg\mish_cuda
# copying build\lib.win-amd64-3.7\mish_cuda\_C.cp37-win_amd64.pyd -> build\bdist.win-amd64\egg\mish_cuda
# copying build\lib.win-amd64-3.7\mish_cuda\__init__.py -> build\bdist.win-amd64\egg\mish_cuda
# byte-compiling build\bdist.win-amd64\egg\mish_cuda\__init__.py to __init__.cpython-37.pyc
# creating stub loader for mish_cuda\_C.cp37-win_amd64.pyd
# byte-compiling build\bdist.win-amd64\egg\mish_cuda\_C.py to _C.cpython-37.pyc
# creating build\bdist.win-amd64\egg\EGG-INFO
# copying src\mish_cuda.egg-info\PKG-INFO -> build\bdist.win-amd64\egg\EGG-INFO
# copying src\mish_cuda.egg-info\SOURCES.txt -> build\bdist.win-amd64\egg\EGG-INFO
# copying src\mish_cuda.egg-info\dependency_links.txt -> build\bdist.win-amd64\egg\EGG-INFO
# copying src\mish_cuda.egg-info\not-zip-safe -> build\bdist.win-amd64\egg\EGG-INFO
# copying src\mish_cuda.egg-info\requires.txt -> build\bdist.win-amd64\egg\EGG-INFO
# copying src\mish_cuda.egg-info\top_level.txt -> build\bdist.win-amd64\egg\EGG-INFO
# writing build\bdist.win-amd64\egg\EGG-INFO\native_libs.txt
# creating dist
# creating 'dist\mish_cuda-0.0.3-py3.7-win-amd64.egg' and adding 'build\bdist.win-amd64\egg' to it
# removing 'build\bdist.win-amd64\egg' (and everything under it)
# Processing mish_cuda-0.0.3-py3.7-win-amd64.egg
# creating c:\users\wmnl\anaconda3\envs\pytorch_e7\lib\site-packages\mish_cuda-0.0.3-py3.7-win-amd64.egg
# Extracting mish_cuda-0.0.3-py3.7-win-amd64.egg to c:\users\wmnl\anaconda3\envs\pytorch_e7\lib\site-packages
# Adding mish-cuda 0.0.3 to easy-install.pth file
#
# Installed c:\users\wmnl\anaconda3\envs\pytorch_e7\lib\site-packages\mish_cuda-0.0.3-py3.7-win-amd64.egg
# Processing dependencies for mish-cuda==0.0.3
# Searching for torch==1.7.1
# Best match: torch 1.7.1
# Adding torch 1.7.1 to easy-install.pth file
# Installing convert-caffe2-to-onnx-script.py script to C:\Users\WMNL\anaconda3\envs\pytorch_E7\Scripts
# Installing convert-caffe2-to-onnx.exe script to C:\Users\WMNL\anaconda3\envs\pytorch_E7\Scripts
# Installing convert-onnx-to-caffe2-script.py script to C:\Users\WMNL\anaconda3\envs\pytorch_E7\Scripts
# Installing convert-onnx-to-caffe2.exe script to C:\Users\WMNL\anaconda3\envs\pytorch_E7\Scripts
#
# Using c:\users\wmnl\anaconda3\envs\pytorch_e7\lib\site-packages
# Searching for numpy==1.21.2
# Best match: numpy 1.21.2
# Adding numpy 1.21.2 to easy-install.pth file
# Installing f2py-script.py script to C:\Users\WMNL\anaconda3\envs\pytorch_E7\Scripts
# Installing f2py.exe script to C:\Users\WMNL\anaconda3\envs\pytorch_E7\Scripts
#
# Using c:\users\wmnl\anaconda3\envs\pytorch_e7\lib\site-packages
# Searching for typing-extensions==3.10.0.2
# Best match: typing-extensions 3.10.0.2
# Adding typing-extensions 3.10.0.2 to easy-install.pth file
#
# Using c:\users\wmnl\anaconda3\envs\pytorch_e7\lib\site-packages
# Finished processing dependencies for mish-cuda==0.0.3

# %%
# !pip install -U PyYAML
# !pip install tensorboard
# !pip install tqdm
# !pip install opencv-python
# !pip install matplotlib
# !pip install scipy
# Out:
# Requirement already satisfied: PyYAML in c:\users\wmnl\anaconda3\envs\pytorch_e7\lib\site-packages (6.0)
# Requirement already satisfied: tensorboard in c:\users\wmnl\anaconda3\envs\pytorch_e7\lib\site-packages (2.7.0)
# Requirement already satisfied: numpy>=1.12.0 in c:\users\wmnl\anaconda3\envs\pytorch_e7\lib\site-packages (from tensorboard) (1.21.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\wmnl\anaconda3\envs\pytorch_e7\lib\site-packages (from tensorboard) (2.3.3)
# Requirement already satisfied: grpcio>=1.24.3 in c:\users\wmnl\anaconda3\envs\pytorch_e7\lib\site-packages (from tensorboard) (1.42.0)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\wmnl\anaconda3\envs\pytorch_e7\lib\site-packages (from tensorboard) (2.0.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\wmnl\anaconda3\envs\pytorch_e7\lib\site-packages (from tensorboard) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\wmnl\anaconda3\envs\pytorch_e7\lib\site-packages (from tensorboard) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\wmnl\anaconda3\envs\pytorch_e7\lib\site-packages (from tensorboard) (3.3.6)
# Requirement already satisfied: absl-py>=0.4 in c:\users\wmnl\anaconda3\envs\pytorch_e7\lib\site-packages (from tensorboard) (1.0.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\wmnl\anaconda3\envs\pytorch_e7\lib\site-packages (from tensorboard) (2.26.0)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\wmnl\anaconda3\envs\pytorch_e7\lib\site-packages (from tensorboard) (58.0.4)
# Requirement already satisfied: wheel>=0.26 in c:\users\wmnl\anaconda3\envs\pytorch_e7\lib\site-packages (from tensorboard) (0.37.0)
# Requirement already satisfied: protobuf>=3.6.0 in c:\users\wmnl\anaconda3\envs\pytorch_e7\lib\site-packages (from tensorboard) (3.19.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\wmnl\anaconda3\envs\pytorch_e7\lib\site-packages (from tensorboard) (1.8.0)
# Requirement already satisfied: six in c:\users\wmnl\anaconda3\envs\pytorch_e7\lib\site-packages (from absl-py>=0.4->tensorboard) (1.16.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\wmnl\anaconda3\envs\pytorch_e7\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\wmnl\anaconda3\envs\pytorch_e7\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\wmnl\anaconda3\envs\pytorch_e7\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\wmnl\anaconda3\envs\pytorch_e7\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\wmnl\anaconda3\envs\pytorch_e7\lib\site-packages (from markdown>=2.6.8->tensorboard) (4.8.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in c:\users\wmnl\anaconda3\envs\pytorch_e7\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in c:\users\wmnl\anaconda3\envs\pytorch_e7\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\wmnl\anaconda3\envs\pytorch_e7\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard) (0.4.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\wmnl\anaconda3\envs\pytorch_e7\lib\site-packages (from requests<3,>=2.21.0->tensorboard) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\wmnl\anaconda3\envs\pytorch_e7\lib\site-packages (from requests<3,>=2.21.0->tensorboard) (2.0.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\wmnl\anaconda3\envs\pytorch_e7\lib\site-packages (from requests<3,>=2.21.0->tensorboard) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\wmnl\anaconda3\envs\pytorch_e7\lib\site-packages (from requests<3,>=2.21.0->tensorboard) (2021.10.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\wmnl\anaconda3\envs\pytorch_e7\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard) (3.1.1)
# Requirement already satisfied: tqdm in c:\users\wmnl\anaconda3\envs\pytorch_e7\lib\site-packages (4.62.3)
# Requirement already satisfied: colorama in c:\users\wmnl\anaconda3\envs\pytorch_e7\lib\site-packages (from tqdm) (0.4.4)
# Requirement already satisfied: opencv-python in c:\users\wmnl\anaconda3\envs\pytorch_e7\lib\site-packages (4.5.4.58)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\wmnl\anaconda3\envs\pytorch_e7\lib\site-packages (from opencv-python) (1.21.2)
# Requirement already satisfied: matplotlib in c:\users\wmnl\anaconda3\envs\pytorch_e7\lib\site-packages (3.5.0)
# Requirement already satisfied: setuptools-scm>=4 in c:\users\wmnl\anaconda3\envs\pytorch_e7\lib\site-packages (from matplotlib) (6.3.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\wmnl\anaconda3\envs\pytorch_e7\lib\site-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\wmnl\anaconda3\envs\pytorch_e7\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\wmnl\anaconda3\envs\pytorch_e7\lib\site-packages (from matplotlib) (4.28.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\wmnl\anaconda3\envs\pytorch_e7\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\wmnl\anaconda3\envs\pytorch_e7\lib\site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\wmnl\anaconda3\envs\pytorch_e7\lib\site-packages (from matplotlib) (21.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\wmnl\anaconda3\envs\pytorch_e7\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\wmnl\anaconda3\envs\pytorch_e7\lib\site-packages (from matplotlib) (1.21.2)
# Requirement already satisfied: six>=1.5 in c:\users\wmnl\anaconda3\envs\pytorch_e7\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: setuptools in c:\users\wmnl\anaconda3\envs\pytorch_e7\lib\site-packages (from setuptools-scm>=4->matplotlib) (58.0.4)
# Requirement already satisfied: tomli>=1.0.0 in c:\users\wmnl\anaconda3\envs\pytorch_e7\lib\site-packages (from setuptools-scm>=4->matplotlib) (1.2.2)
# Collecting scipy
#   Downloading scipy-1.7.2-cp37-cp37m-win_amd64.whl (34.1 MB)
# Requirement already satisfied: numpy<1.23.0,>=1.16.5 in c:\users\wmnl\anaconda3\envs\pytorch_e7\lib\site-packages (from scipy) (1.21.2)
# Installing collected packages: scipy
# Successfully installed scipy-1.7.2

# %%
# %cd C:/Users/WMNL/scaled-yolov4_E7/ScaledYOLOv4/
# Out:
# C:\Users\WMNL\scaled-yolov4_E7\ScaledYOLOv4

# %% [markdown]
# # Download Correctly Formatted Custom Dataset
#
# We'll download our dataset from Roboflow. Use the "**YOLOv5 PyTorch**" export format. Note that the Ultralytics implementation calls for a YAML file defining where your training and test data is. The Roboflow export also writes this format for us.
#
# To get your data into Roboflow, follow the [Getting Started Guide](https://blog.roboflow.ai/getting-started-with-roboflow/).

# %% [markdown]
# ![YOLOv5 PyTorch export](https://i.imgur.com/5vr9G2u.png)

# %%
# #follow the link below to get your download code from from Roboflow
# !pip install -q roboflow
# from roboflow import Roboflow
# rf = Roboflow(model_format="yolov5", notebook="roboflow-scaled-yolov4")

# %%
# Export code snippet and paste here
# %cd C:/Users/WMNL/scaled-yolov4_E7
#after following the link above, recieve python code with these fields filled in
#from roboflow import Roboflow
#rf = Roboflow(api_key="YOUR API KEY HERE")
#project = rf.workspace().project("YOUR PROJECT")
#dataset = project.version("YOUR VERSION").download("yolov5")
# Out:
# C:\Users\WMNL\scaled-yolov4_E7

# %%
# this is the YAML file Roboflow wrote for us that we're loading into this notebook with our data
# %cat data.yaml
# Out:
# 'cat' 不是內部或外部命令、可執行的程式或批次檔。

# %% [markdown]
# #Inspect Model Configuration and Architecture
#
# Let's look at the Scaled-YOLOv4 Configuration architecture

# %%
# %cat /content/ScaledYOLOv4/models/yolov4-csp.yaml
# Out:
# # parameters
# nc: 80  # number of classes
# depth_multiple: 1.0  # model depth multiple
# width_multiple: 1.0  # layer channel multiple
#
# # anchors
# anchors:
#   - [12,16, 19,36, 40,28]  # P3/8
#   - [36,75, 76,55, 72,146]  # P4/16
#   - [142,110, 192,243, 459,401]  # P5/32
#
# # yolov4-csp backbone
# backbone:
#   # [from, number, module, args]
#   [[-1, 1, Conv, [32, 3, 1]],  # 0
#    [-1, 1, Conv, [64, 3, 2]],  # 1-P1/2
#    [-1, 1, Bottleneck, [64]],
#    [-1, 1, Conv, [128, 3, 2]],  # 3-P2/4
#    [-1, 2, BottleneckCSP, [128]],
#    [-1, 1, Conv, [256, 3, 2]],  # 5-P3/8
#    [-1, 8, BottleneckCSP, [256]],
#    [-1, 1, Conv, [512, 3, 2]],  # 7-P4/16
#    [-1, 8, BottleneckCSP, [512]],
#    [-1, 1, Conv, [1024, 3, 2]], # 9-P5/32
#    [-1, 4, BottleneckCSP, [1024]],  # 10
#   ]
#
# # yolov4-csp head
# # na = len(anchors[0])
# head:
#   [[-1, 1, SPPCSP, [512]], # 11
#    [-1, 1, Conv, [256, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [8, 1, Conv, [256, 1, 1]], # route backbone P4
#    [[-1, -2], 1, Concat, [1]],
#    [-1, 2, BottleneckCSP2, [256]], # 16
#    [-1, 1, Conv, [128, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [6, 1, Conv, [128, 1, 1]], # route backbone P3
#    [[-1, -2], 1, Concat, [1]],
#    [-1, 2, BottleneckCSP2, [128]], # 21
#    [-1, 1, Conv, [256, 3, 1]],
#    [-2, 1, Conv, [256, 3, 2]],
#    [[-1, 16], 1, Concat, [1]],  # cat
#    [-1, 2, BottleneckCSP2, [256]], # 25
#    [-1, 1, Conv, [512, 3, 1]],
#    [-2, 1, Conv, [512, 3, 2]],
#    [[-1, 11], 1, Concat, [1]],  # cat
#    [-1, 2, BottleneckCSP2, [512]], # 29
#    [-1, 1, Conv, [1024, 3, 1]],
#
#    [[22,26,30], 1, Detect, [nc, anchors]],   # Detect(P3, P4, P5)
#   ]

# %% [markdown]
# # Train Custom Scaled-YOLOv4 Detector
#
# ### Next, we'll fire off training!
#
#
# Here, we are able to pass a number of arguments:
# - **img:** define input image size
# - **batch:** determine batch size
# - **epochs:** define the number of training epochs. (Note: often, 3000+ are common here!)
# - **data:** set the path to our yaml file
# - **cfg:** specify our model configuration
# - **weights:** specify a custom path to weights.
# - **name:** result names
# - **nosave:** only save the final checkpoint
# - **cache:** cache images for faster training

# %%
# !pip list
# Out:
# Package                 Version
# ----------------------- ---------
# absl-py                 1.0.0
# argcomplete             1.12.3
# argon2-cffi             20.1.0
# async-generator         1.10
# attrs                   21.2.0
# backcall                0.2.0
# bleach                  4.0.0
# cachetools              4.2.4
# certifi                 2021.10.8
# cffi                    1.15.0
# charset-normalizer      2.0.7
# colorama                0.4.4
# debugpy                 1.5.1
# decorator               5.1.0
# defusedxml              0.7.1
# entrypoints             0.3
# google-auth             2.3.3
# google-auth-oauthlib    0.4.6
# grpcio                  1.42.0
# idna                    3.3
# importlib-metadata      4.8.1
# ipykernel               6.4.1
# ipython                 7.29.0
# ipython-genutils        0.2.0
# ipywidgets              7.6.5
# jedi                    0.18.0
# Jinja2                  3.0.2
# jsonschema              3.2.0
# jupyter                 1.0.0
# jupyter-client          7.0.6
# jupyter-console         6.4.0
# jupyter-core            4.9.1
# jupyterlab-pygments     0.1.2
# jupyterlab-widgets      1.0.0
# Markdown                3.3.6
# MarkupSafe              2.0.1
# matplotlib-inline       0.1.2
# mish-cuda               0.0.3
# mistune                 0.8.4
# mkl-fft                 1.3.1
# mkl-random              1.2.2
# mkl-service             2.4.0
# nbclient                0.5.3
# nbconvert               6.1.0
# nbformat                5.1.3
# nest-asyncio            1.5.1
# notebook                6.4.6
# numpy                   1.21.2
# oauthlib                3.1.1
# olefile                 0.46
# packaging               21.0
# pandocfilters           1.4.3
# parso                   0.8.2
# pickleshare             0.7.5
# Pillow                  8.4.0
# pip                     21.2.4
# prometheus-client       0.12.0
# prompt-toolkit          3.0.20
# protobuf                3.19.1
# pyasn1                  0.4.8
# pyasn1-modules          0.2.8
# pycparser               2.21
# Pygments                2.10.0
# pyparsing               3.0.4
# pyrsistent              0.18.0
# python-dateutil         2.8.2
# pywin32                 228
# pywinpty                0.5.7
# PyYAML                  6.0
# pyzmq                   22.2.1
# qtconsole               5.1.1
# QtPy                    1.10.0
# requests                2.26.0
# requests-oauthlib       1.3.0
# rsa                     4.7.2
# Send2Trash              1.8.0
# setuptools              58.0.4
# six                     1.16.0
# tensorboard             2.7.0
# tensorboard-data-server 0.6.1
# tensorboard-plugin-wit  1.8.0
# terminado               0.9.4
# testpath                0.5.0
# torch                   1.7.1
# torchaudio              0.7.2
# torchvision             0.8.2
# tornado                 6.1
# traitlets               5.1.1
# typing-extensions       3.10.0.2
# urllib3                 1.26.7
# wcwidth                 0.2.5
# webencodings            0.5.1
# Werkzeug                2.0.2
# wheel                   0.37.0
# widgetsnbextension      3.5.1
# wincertstore            0.2
# zipp                    3.6.0

# %%
# !nvcc -V
print(torch.cuda.device_count())
print(torch.cuda.is_available())
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2021 NVIDIA Corporation
# Built on Sun_Feb_14_22:08:44_Pacific_Standard_Time_2021
# Cuda compilation tools, release 11.2, V11.2.152
# Build cuda_11.2.r11.2/compiler.29618528_0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11548/1164852972.py in <module>
#       1 get_ipython().system('nvcc -V')
# ----> 2 print(torch.cuda.device_count())
#       3 print(torch.cuda.is_available())
#
# NameError: name 'torch' is not defined

# %%
# %%time
# train scaled-YOLOv4 on custom data for 100 epochs
# time its performance

# python train.py --img 416 --batch 4 --epochs 3000 --device 0 --data ../data.yaml --cfg ./models/yolov4-csp.yaml --weights '' --name yolov4-csp-416-4-3000-results  --cache

# %cd C:/Users/WMNL/scaled-yolov4_E7/ScaledYOLOv4/
# !python train.py --img 416 --batch 4 --epochs 1000 --device 0 --data ../data.yaml --cfg ./models/yolov4-csp.yaml --weights '' --name yolov4-csp-416-4-1000-results  --cache
# Out:
# C:\Users\WMNL\scaled-yolov4_E7\ScaledYOLOv4
# ^C
# Wall time: 3min 34s

# %% [markdown]
# # Evaluate Custom Scaled-YOLOv4 Detector Performance

# %% [markdown]
# Training losses and performance metrics are saved to Tensorboard and also to a logfile defined above with the **--name** flag when we train. In our case, we named this `yolov5s_results`. (If given no name, it defaults to `results.txt`.) The results file is plotted as a png after training completes.
#
# Note from Glenn: Partially completed `results.txt` files can be plotted with `from utils.utils import plot_results; plot_results()`.

# %%
# Start tensorboard
# Launch after you have started training
# logs save in the folder "runs"
# %load_ext tensorboard
# %tensorboard --logdir runs

# %%
# we can also output some older school graphs if the tensor board isn't working for whatever reason... 
#from utils.general import plot_results  # plot results.txt as results.png
from IPython.display import Image, display
display(Image('/content/ScaledYOLOv4/runs/exp0_yolov4-csp-results/results.png'))  # view results.png

# %% [markdown]
# ### Curious? Visualize Our Training Data with Labels
#
# After training starts, view `train*.jpg` images to see training images, labels and augmentation effects.
#
# Note a mosaic dataloader is used for training (shown below), a new dataloading concept developed by Glenn Jocher and first featured in [YOLOv4](https://arxiv.org/abs/2004.10934).

# %%
# first, display our ground truth data
print("GROUND TRUTH TRAINING DATA:")
Image(filename='/content/ScaledYOLOv4/runs/exp0_yolov4-csp-results/test_batch0_gt.jpg', width=900)

# %%
# print out an augmented training example
print("GROUND TRUTH AUGMENTED TRAINING DATA:")
Image(filename='/content/ScaledYOLOv4/runs/exp0_yolov4-csp-results/train_batch0.jpg', width=900)

# %% [markdown]
# #Run Inference  With Trained Weights
# Run inference with a pretrained checkpoint on contents of `test/images` folder downloaded from Roboflow.

# %%
# trained weights are saved by default in our weights folder
# %ls runs/
# Out:
# exp0_yolov4-csp-results/  exp1_yolov4-csp-results/

# %%
# %ls ./runs/exp0_yolov4-csp-results/weights
# Out:
# best_yolov4-csp-results.pt        last_003.pt  last_008.pt
# best_yolov4-csp-results_strip.pt  last_004.pt  last_009.pt
# last_000.pt                       last_005.pt  last_yolov4-csp-results.pt
# last_001.pt                       last_006.pt  last_yolov4-csp-results_strip.pt
# last_002.pt                       last_007.pt

# %%
# when we ran this, we saw .007 second inference time. That is 140 FPS on a TESLA P100!
# use the best weights!
# %cd C:/Users/WMNL/KevinGG/scaled-yolov4_E7/ScaledYOLOv4/
# !python detect.py --weights ./runs/exp1_yolov4-csp-1100-4-3000-results/weights/best_yolov4-csp-1100-4-3000-results.pt --img 1100 --conf 0.4 --source ../test/images

# %cd C:/Users/WMNL/KevinGG/scaled-yolov4_E7/ScaledYOLOv4-cpu/
# !python detect.py --cfg models/yolov4-csp.cfg --weights ./runs/exp0_yolov4-csp-800-2-3000-cpu/weights/best_yolov4-csp-800-2-3000-cpu.pt --img 800 --conf 0.4 --source ../test/images
# Out:
# C:\Users\WMNL\KevinGG\scaled-yolov4_E7\ScaledYOLOv4
# C:\Users\WMNL\KevinGG\scaled-yolov4_E7\ScaledYOLOv4-cpu
# Namespace(agnostic_nms=False, augment=False, cfg='models/yolov4-csp.cfg', classes=None, conf_thres=0.4, device='', img_size=800, iou_thres=0.5, names='../data.names', output='inference/output', save_txt=False, source='../test/images', update=False, view_img=False, weights=['./runs/exp0_yolov4-csp-800-2-3000-cpu/weights/best_yolov4-csp-800-2-3000-cpu.pt'])
# Using CUDA device0 _CudaDeviceProperties(name='NVIDIA GeForce RTX 3080', total_memory=10239MB)
#
# Model Summary: 342 layers, 5.29214e+07 parameters, 5.29214e+07 gradients
# image 1/53 C:\Users\WMNL\KevinGG\scaled-yolov4_E7\test\images\screenshot (1).png: 480x800 2 npc_Nissas, 5 Buybutton 1s, 1 Buybutton 2s, 1 update store Checkbutton 1s, 1 sliding areas, Done. (0.036s)
# image 2/53 C:\Users\WMNL\KevinGG\scaled-yolov4_E7\test\images\screenshot (10).png: 480x800 1 npc_Nissas, 4 Buybutton 1s, 1 Buybutton 2s, 1 update store Checkbutton 1s, 1 sliding areas, Done. (0.027s)
# image 3/53 C:\Users\WMNL\KevinGG\scaled-yolov4_E7\test\images\screenshot (11).png: 480x800 1 npc_Nissas, 4 Buybutton 1s, 1 Buybutton 2s, 1 update store Checkbutton 1s, 1 sliding areas, Done. (0.023s)
# image 4/53 C:\Users\WMNL\KevinGG\scaled-yolov4_E7\test\images\screenshot (18).png: 480x800 1 Buybutton 2s, Done. (0.021s)
# image 5/53 C:\Users\WMNL\KevinGG\scaled-yolov4_E7\test\images\screenshot (19).png: 480x800 1 Buybutton 2s, Done. (0.021s)
# image 6/53 C:\Users\WMNL\KevinGG\scaled-yolov4_E7\test\images\screenshot (2).png: 480x800 2 npc_Nissas, 5 Buybutton 1s, 1 Buybutton 2s, 1 update store Checkbutton 1s, 1 sliding areas, Done. (0.021s)
# image 7/53 C:\Users\WMNL\KevinGG\scaled-yolov4_E7\test\images\screenshot (20).png: 480x800 Done. (0.021s)
# image 8/53 C:\Users\WMNL\KevinGG\scaled-yolov4_E7\test\images\screenshot (21).png: 480x800 4 Buybutton 1s, 1 Buybutton 2s, 1 update store Checkbutton 1s, 1 sliding areas, Done. (0.023s)
# image 9/53 C:\Users\WMNL\KevinGG\scaled-yolov4_E7\test\images\screenshot (22).png: 480x800 2 npc_Nissas, 4 Buybutton 1s, 1 Buybutton 2s, 1 update store Checkbutton 1s, 1 sliding areas, Done. (0.025s)
# image 10/53 C:\Users\WMNL\KevinGG\scaled-yolov4_E7\test\images\screenshot (23).png: 480x800 4 Buybutton 1s, 1 update store Checkbutton 1s, 1 sliding areas, Done. (0.022s)
# image 11/53 C:\Users\WMNL\KevinGG\scaled-yolov4_E7\test\images\screenshot (24).png: 480x800 1 npc_Nissas, 4 Buybutton 1s, 1 Buybutton 2s, 1 update store Checkbutton 1s, 1 sliding areas, Done. (0.023s)
# image 12/53 C:\Users\WMNL\KevinGG\scaled-yolov4_E7\test\images\screenshot (25).png: 480x800 1 Mystery bookmarks, 1 Buybutton 2s, Done. (0.026s)
# image 13/53 C:\Users\WMNL\KevinGG\scaled-yolov4_E7\test\images\screenshot (26).png: 480x800 1 Mystery bookmarks, 1 Buybutton 2s, Done. (0.024s)
# image 14/53 C:\Users\WMNL\KevinGG\scaled-yolov4_E7\test\images\screenshot (27).png: 480x800 1 Mystery bookmarks, 1 Buybutton 2s, Done. (0.024s)
# image 15/53 C:\Users\WMNL\KevinGG\scaled-yolov4_E7\test\images\screenshot (28).png: 480x800 1 Mystery bookmarks, 1 Buybutton 2s, Done. (0.024s)
# image 16/53 C:\Users\WMNL\KevinGG\scaled-yolov4_E7\test\images\screenshot (29).png: 480x800 2 npc_Nissas, 5 Buybutton 1s, 1 update store Checkbutton 1s, 1 sliding areas, Done. (0.025s)
# image 17/53 C:\Users\WMNL\KevinGG\scaled-yolov4_E7\test\images\screenshot (3).png: 480x800 1 npc_Nissas, 6 Buybutton 1s, 1 Buybutton 2s, 1 update store Checkbutton 1s, 1 sliding areas, Done. (0.025s)
# image 18/53 C:\Users\WMNL\KevinGG\scaled-yolov4_E7\test\images\screenshot (30).png: 480x800 2 npc_Nissas, 5 Buybutton 1s, 1 Buybutton 2s, 1 update store Checkbutton 1s, 1 sliding areas, Done. (0.026s)
# image 19/53 C:\Users\WMNL\KevinGG\scaled-yolov4_E7\test\images\screenshot (31).png: 480x800 1 Mystery bookmarks, 5 Buybutton 1s, 2 Buybutton 2s, 1 update store Checkbutton 1s, 1 sliding areas, Done. (0.028s)
# image 20/53 C:\Users\WMNL\KevinGG\scaled-yolov4_E7\test\images\screenshot (32).png: 480x800 1 npc_Nissas, 5 Buybutton 1s, 1 update store Checkbutton 1s, 1 sliding areas, Done. (0.027s)
# image 21/53 C:\Users\WMNL\KevinGG\scaled-yolov4_E7\test\images\screenshot (33).png: 480x800 3 npc_Nissas, 3 npc_Nonoris, 2 Mystery bookmarks, 5 Buybutton 1s, 1 Buybutton 2s, 1 sliding areas, Done. (0.027s)
# image 22/53 C:\Users\WMNL\KevinGG\scaled-yolov4_E7\test\images\screenshot (34).png: 480x800 1 npc_Nissas, 1 Mystery bookmarks, 6 Buybutton 1s, 1 Buybutton 2s, 1 sliding areas, Done. (0.027s)
# image 23/53 C:\Users\WMNL\KevinGG\scaled-yolov4_E7\test\images\screenshot (35).png: 480x800 2 moneys, 1 npc_Nissas, 1 npc_Nonoris, 2 Mystery bookmarks, 5 Buybutton 1s, 1 Buybutton 2s, 1 sliding areas, Done. (0.027s)
# image 24/53 C:\Users\WMNL\KevinGG\scaled-yolov4_E7\test\images\screenshot (36).png: 480x800 1 npc_Nissas, 5 Buybutton 1s, 1 Buybutton 2s, 1 update store Checkbutton 1s, 1 sliding areas, Done. (0.028s)
# image 25/53 C:\Users\WMNL\KevinGG\scaled-yolov4_E7\test\images\screenshot (37).png: 480x800 1 npc_Nissas, 5 Buybutton 1s, 1 Buybutton 2s, 1 update store Checkbutton 1s, 1 sliding areas, Done. (0.028s)
# image 26/53 C:\Users\WMNL\KevinGG\scaled-yolov4_E7\test\images\screenshot (38).png: 480x800 1 Mystery bookmarks, 6 Buybutton 1s, 1 Buybutton 2s, 1 update store Checkbutton 1s, 1 sliding areas, Done. (0.029s)
# image 27/53 C:\Users\WMNL\KevinGG\scaled-yolov4_E7\test\images\screenshot (39).png: 480x800 1 Mystery bookmarks, 1 Buybutton 2s, Done. (0.029s)
# image 28/53 C:\Users\WMNL\KevinGG\scaled-yolov4_E7\test\images\screenshot (4).png: 480x800 3 npc_Nissas, 5 Buybutton 1s, 1 Buybutton 2s, 1 update store Checkbutton 1s, 1 sliding areas, Done. (0.029s)
# image 29/53 C:\Users\WMNL\KevinGG\scaled-yolov4_E7\test\images\screenshot (40).png: 480x800 1 Mystery bookmarks, 1 Buybutton 2s, Done. (0.029s)
# image 30/53 C:\Users\WMNL\KevinGG\scaled-yolov4_E7\test\images\screenshot (41).png: 480x800 1 Mystery bookmarks, 1 Buybutton 2s, Done. (0.030s)
# image 31/53 C:\Users\WMNL\KevinGG\scaled-yolov4_E7\test\images\screenshot (42).png: 480x800 1 Mystery bookmarks, 1 Buybutton 2s, Done. (0.030s)
# image 32/53 C:\Users\WMNL\KevinGG\scaled-yolov4_E7\test\images\screenshot (43).png: 480x800 1 Mystery bookmarks, 1 Buybutton 2s, Done. (0.031s)
# image 33/53 C:\Users\WMNL\KevinGG\scaled-yolov4_E7\test\images\screenshot (44).png: 480x800 1 Mystery bookmarks, 1 Buybutton 2s, Done. (0.031s)
# image 34/53 C:\Users\WMNL\KevinGG\scaled-yolov4_E7\test\images\screenshot (45).png: 480x800 1 Mystery bookmarks, 1 Buybutton 2s, Done. (0.031s)
# image 35/53 C:\Users\WMNL\KevinGG\scaled-yolov4_E7\test\images\screenshot (46).png: 480x800 1 Mystery bookmarks, 1 Buybutton 2s, Done. (0.032s)
# image 36/53 C:\Users\WMNL\KevinGG\scaled-yolov4_E7\test\images\screenshot (47).png: 480x800 1 Mystery bookmarks, 1 Buybutton 2s, Done. (0.032s)
# image 37/53 C:\Users\WMNL\KevinGG\scaled-yolov4_E7\test\images\screenshot (48).png: 480x800 1 Mystery bookmarks, 1 Buybutton 2s, Done. (0.033s)
# image 38/53 C:\Users\WMNL\KevinGG\scaled-yolov4_E7\test\images\screenshot (49).png: 480x800 1 Mystery bookmarks, 1 Buybutton 2s, Done. (0.034s)
# image 39/53 C:\Users\WMNL\KevinGG\scaled-yolov4_E7\test\images\screenshot (5).png: 480x800 3 npc_Nissas, 5 Buybutton 1s, 1 Buybutton 2s, 1 update store Checkbutton 1s, 1 sliding areas, Done. (0.061s)
# image 40/53 C:\Users\WMNL\KevinGG\scaled-yolov4_E7\test\images\screenshot (50).png: 480x800 1 Mystery bookmarks, 1 Buybutton 2s, Done. (0.061s)
# image 41/53 C:\Users\WMNL\KevinGG\scaled-yolov4_E7\test\images\screenshot (51).png: 480x800 1 Mystery bookmarks, 1 Buybutton 2s, Done. (0.056s)
# image 42/53 C:\Users\WMNL\KevinGG\scaled-yolov4_E7\test\images\screenshot (52).png: 480x800 1 Mystery bookmarks, 1 Buybutton 2s, Done. (0.055s)
# image 43/53 C:\Users\WMNL\KevinGG\scaled-yolov4_E7\test\images\screenshot (53).png: 480x800 1 Mystery bookmarks, 1 Buybutton 2s, Done. (0.054s)
# image 44/53 C:\Users\WMNL\KevinGG\scaled-yolov4_E7\test\images\screenshot (54).png: 480x800 4 Buybutton 1s, 1 Buybutton 2s, 1 update store Checkbutton 1s, 1 sliding areas, Done. (0.054s)
# image 45/53 C:\Users\WMNL\KevinGG\scaled-yolov4_E7\test\images\screenshot (55).png: 480x800 4 Buybutton 1s, 1 Buybutton 2s, 1 update store Checkbutton 1s, 1 sliding areas, Done. (0.054s)
# image 46/53 C:\Users\WMNL\KevinGG\scaled-yolov4_E7\test\images\screenshot (56).png: 480x800 4 Buybutton 1s, 1 Buybutton 2s, 1 update store Checkbutton 1s, 1 sliding areas, Done. (0.053s)
# image 47/53 C:\Users\WMNL\KevinGG\scaled-yolov4_E7\test\images\screenshot (57).png: 480x800 4 Buybutton 1s, 1 Buybutton 2s, 1 update store Checkbutton 1s, 1 sliding areas, Done. (0.053s)
# image 48/53 C:\Users\WMNL\KevinGG\scaled-yolov4_E7\test\images\screenshot (58).png: 480x800 1 npc_Nissas, 5 Buybutton 1s, 1 update store Checkbutton 1s, 1 sliding areas, Done. (0.053s)
# image 49/53 C:\Users\WMNL\KevinGG\scaled-yolov4_E7\test\images\screenshot (59).png: 480x800 2 npc_Nissas, 5 Buybutton 1s, 1 Buybutton 2s, 1 update store Checkbutton 1s, 1 sliding areas, Done. (0.052s)
# image 50/53 C:\Users\WMNL\KevinGG\scaled-yolov4_E7\test\images\screenshot (6).png: 480x800 2 npc_Nissas, 5 Buybutton 1s, 1 Buybutton 2s, 1 update store Checkbutton 1s, 1 sliding areas, Done. (0.052s)
# image 51/53 C:\Users\WMNL\KevinGG\scaled-yolov4_E7\test\images\screenshot (60).png: 480x800 1 Buybutton 2s, Done. (0.052s)
# image 52/53 C:\Users\WMNL\KevinGG\scaled-yolov4_E7\test\images\screenshot (61).png: 480x800 1 Buybutton 2s, Done. (0.020s)
# image 53/53 C:\Users\WMNL\KevinGG\scaled-yolov4_E7\test\images\screenshot (7).png: 480x800 2 Mystery bookmarks, 5 Buybutton 1s, 1 Buybutton 2s, 1 sliding areas, Done. (0.022s)
# Results saved to inference\output
# Done. (7.091s)

# %%
#display inference on ALL test images
#this looks much better with longer training above
import glob
from IPython.display import Image, display

for imageName in glob.glob('./inference/output/*.png'): #assuming JPG
    display(Image(filename=imageName))
    print("\n")

# %% [markdown]
# # Export Trained Weights for Future Inference
#
# Now that you have trained your custom detector, you can export the trained weights you have made here for inference on your device elsewhere

# %%
from google.colab import files
files.download('./runs/exp0_yolov4-csp-results/weights/best_yolov4-csp-results.pt')

# %% [markdown]
# ## Congrats!
#
# Hope you enjoyed this!
#
# --Team [Roboflow](https://roboflow.ai)
